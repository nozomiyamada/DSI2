# %% [markdown]
# # import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rcParams["figure.figsize"] = (10, 8)
import seaborn as sns
from pandas_profiling import ProfileReport

# %% [markdown]
# # load cleaned data

# %%
act = pd.read_csv('data/act.csv') # 51 states * 3 years
act
# Out:
#      Year          State  Participation  Composite
# 0    2017        Alabama           1.00       19.2
# 1    2017         Alaska           0.65       19.8
# 2    2017        Arizona           0.62       19.7
# 3    2017       Arkansas           1.00       19.4
# 4    2017     California           0.31       22.8
# ..    ...            ...            ...        ...
# 148  2019       Virginia           0.21       24.0
# 149  2019     Washington           0.24       22.1
# 150  2019  West Virginia           0.49       20.8
# 151  2019      Wisconsin           1.00       20.3
# 152  2019        Wyoming           1.00       19.8
#
# [153 rows x 4 columns]

# %% [markdown]
# # visualization

# %%
act.groupby('Year')[['Participation','Composite']].corr()
# Out:
#                     Participation  Composite
# Year
# 2017 Participation       1.000000  -0.858134
#      Composite          -0.858134   1.000000
# 2018 Participation       1.000000  -0.863688
#      Composite          -0.863688   1.000000
# 2019 Participation       1.000000  -0.866819
#      Composite          -0.866819   1.000000

# %%
sns.scatterplot(
    y='Participation',
    x='Composite',
    hue='Year',
    palette='dark',
    data=act)
# Out:
# <AxesSubplot:xlabel='Composite', ylabel='Participation'>

# %%
plt.figure(figsize=(20, 15))
sns.barplot(
    y='State',
    x='Participation',
    hue='Year',
    order=act.groupby('State')['Participation'].mean().sort_values(ascending=False).index,
    data=act)
# Out:
# <AxesSubplot:xlabel='Participation', ylabel='State'>
